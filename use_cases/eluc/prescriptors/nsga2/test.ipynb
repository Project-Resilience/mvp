# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from pathlib import Path
import pandas as pd

from prescriptors.nsga2.torch_prescriptor import Candidate
from data import constants
from data.eluc_data import ELUCData
from data.torch_data import TorchDataset

# %%
path = Path("prescriptors/nsga2/trained_prescriptors/test")
for gen in [0, 1, 5, 10, 25, 50, 100]:
    results_df = pd.read_csv(path / f"gen_{gen}.csv")
    plt.scatter(results_df["eluc"], results_df["change"], label=gen)
plt.legend()
plt.show()
